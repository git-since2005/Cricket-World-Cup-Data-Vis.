# %% [markdown]
# # IPL Winning Team Predictor

# %% [markdown]
# ## Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# !pip uninstall scikit-learn -y

# %%
# !pip install -U scikit-learn==0.24.1

# %% [markdown]
# ## Reading the csv files

# %% [markdown]
# ### Matches from 2008 to 2021

# %%
matches_till_2021 = pd.read_csv("Dataset/IPL_Matches_2008_2021.csv")
matches_till_2021.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1254117      Dubai  2021-10-15   2021        Final
# 1  1254116    Sharjah  2021-10-13   2021  Qualifier 2
# 2  1254115    Sharjah  2021-10-11   2021   Eliminator
# 3  1254114      Dubai  2021-10-10   2021  Qualifier 1
# 4  1254088  Abu Dhabi  2021-10-08   2021           55
#
#                          Team1                  Team2  \
# 0          Chennai Super Kings  Kolkata Knight Riders
# 1               Delhi Capitals  Kolkata Knight Riders
# 2  Royal Challengers Bangalore  Kolkata Knight Riders
# 3               Delhi Capitals    Chennai Super Kings
# 4               Mumbai Indians    Sunrisers Hyderabad
#
#                                  Venue                   TossWinner  \
# 0  Dubai International Cricket Stadium        Kolkata Knight Riders
# 1              Sharjah Cricket Stadium        Kolkata Knight Riders
# 2              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 3  Dubai International Cricket Stadium          Chennai Super Kings
# 4     Zayed Cricket Stadium, Abu Dhabi               Mumbai Indians
#
#   TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 0        field         N    Chennai Super Kings     Runs    27.0    NaN
# 1        field         N  Kolkata Knight Riders  Wickets     3.0    NaN
# 2          bat         N  Kolkata Knight Riders  Wickets     4.0    NaN
# 3        field         N    Chennai Super Kings  Wickets     4.0    NaN
# 4          bat         N         Mumbai Indians     Runs    42.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0    F du Plessis  ['RD Gaikwad', 'F du Plessis', 'RV Uthappa', '...
# 1         VR Iyer  ['PP Shaw', 'S Dhawan', 'MP Stoinis', 'SS Iyer...
# 2       SP Narine  ['D Padikkal', 'V Kohli', 'KS Bharat', 'GJ Max...
# 3      RD Gaikwad  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'AR Patel',...
# 4    Ishan Kishan  ['RG Sharma', 'Ishan Kishan', 'HH Pandya', 'KA...
#
#                                         Team2Players                Umpire1  \
# 0  ['Shubman Gill', 'VR Iyer', 'N Rana', 'SP Nari...            Nitin Menon
# 1  ['Shubman Gill', 'VR Iyer', 'N Rana', 'RA Trip...  KN Ananthapadmanabhan
# 2  ['Shubman Gill', 'VR Iyer', 'RA Tripathi', 'N ...            CB Gaffaney
# 3  ['RD Gaikwad', 'F du Plessis', 'RV Uthappa', '...            Nitin Menon
# 4  ['JJ Roy', 'Abhishek Sharma', 'MK Pandey', 'Mo...           Tapan Sharma
#
#           Umpire2
# 0  RK Illingworth
# 1        MA Gough
# 2       VK Sharma
# 3  RK Illingworth
# 4       VK Sharma

# %% [markdown]
# ### Matches played in 2022

# %%
matches_2022 = pd.read_csv("Dataset/IPL_Matches_2022.csv")
matches_2022.head(5)
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin  method  \
# 0         N               Gujarat Titans  Wickets       7     NaN
# 1         N             Rajasthan Royals  Wickets       7     NaN
# 2         N  Royal Challengers Bangalore     Runs      14     NaN
# 3         N               Gujarat Titans  Wickets       7     NaN
# 4         N                 Punjab Kings  Wickets       5     NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %% [markdown]
# ### Combining the 2 datasets - (2008 to 2021) & 2022 matches played

# %%
frames = [matches_2022, matches_till_2021]
matches = pd.concat(frames)
matches.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %% [markdown]
# ### Displaying the IPL Seasons

# %%
# First, I'm following a uniform standard for the seasons
# Extracting the year part from the dates

matches['Season'] = matches['Season'].replace('2007/08','2008')
matches['Season'] = matches['Season'].str.replace('2020/21','2020')
matches['Season'] = matches['Season'].str.replace('2009/10','2010')
matches['Season'] = matches['Season'].replace(np.nan, '2022')

matches.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %% [markdown]
# ### Ball by Ball data

# %%
matches['Season'].unique()
# Out:
# array(['2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2010', '2009', '2008'],
#       dtype=object)

# %%
delivery_till_2021 = pd.read_csv('Dataset/IPL_Ball_by_Ball_2008_2021.csv')
delivery_2022 = pd.read_csv("Dataset/IPL_Ball_by_Ball_2022.csv")

frames = [delivery_2022, delivery_till_2021]
delivery = pd.concat(frames)
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 225954 entries, 0 to 208041
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
#  15  fielders_involved  7988 non-null    object
#  16  BattingTeam        225954 non-null  object
# dtypes: int64(9), object(8)
# memory usage: 31.0+ MB

# %% [markdown]
# ## Adding the field 'BowlingTeam' in the delivery dataframe

# %%
#Creating a reduced data frame from matches, with the match ID and the participating teams
data = {
    'ID': matches['ID'],
    'Team1': matches['Team1'],
    'Team2': matches['Team2']
}

matches_subset = pd.DataFrame(data)


#Inner joining this reduced matches dataframe with deliveries dataframe on 'ID'
delivery['BowlingTeam'] = "" #Creating an empty attribute called BowlingTeam in deliveries
delivery = pd.merge(matches_subset, delivery, on='ID', how='inner')

#Filling the BowlingTeam attribute with the appropriate team names
for idx in delivery.index:
    delivery['BowlingTeam'][idx] = delivery['Team1'][idx] if delivery['BattingTeam'][idx] != delivery['Team1'][idx] else delivery['Team2'][idx]
        
delivery.drop(['Team1', 'Team2'], axis = 1)

delivery.head(10)
# Out:
#         ID             Team1           Team2  innings  overs  ballnumber  \
# 0  1312200  Rajasthan Royals  Gujarat Titans        1      0           1
# 1  1312200  Rajasthan Royals  Gujarat Titans        1      0           2
# 2  1312200  Rajasthan Royals  Gujarat Titans        1      0           3
# 3  1312200  Rajasthan Royals  Gujarat Titans        1      0           4
# 4  1312200  Rajasthan Royals  Gujarat Titans        1      0           5
# 5  1312200  Rajasthan Royals  Gujarat Titans        1      0           6
# 6  1312200  Rajasthan Royals  Gujarat Titans        1      1           1
# 7  1312200  Rajasthan Royals  Gujarat Titans        1      1           2
# 8  1312200  Rajasthan Royals  Gujarat Titans        1      1           3
# 9  1312200  Rajasthan Royals  Gujarat Titans        1      1           4
#
#         batter          bowler  non-striker extra_type  batsman_run  \
# 0  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 1  YBK Jaiswal  Mohammed Shami   JC Buttler    legbyes            0
# 2   JC Buttler  Mohammed Shami  YBK Jaiswal        NaN            1
# 3  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 4  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 5  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 6   JC Buttler      Yash Dayal  YBK Jaiswal        NaN            0
# 7   JC Buttler      Yash Dayal  YBK Jaiswal        NaN            0
# 8   JC Buttler      Yash Dayal  YBK Jaiswal        NaN            4
# 9   JC Buttler      Yash Dayal  YBK Jaiswal        NaN            0
#
#    extras_run  total_run  non_boundary  isWicketDelivery player_out kind  \
# 0           0          0             0                 0        NaN  NaN
# 1           1          1             0                 0        NaN  NaN
# 2           0          1             0                 0        NaN  NaN
# 3           0          0             0                 0        NaN  NaN
# 4           0          0             0                 0        NaN  NaN
# 5           0          0             0                 0        NaN  NaN
# 6           0          0             0                 0        NaN  NaN
# 7           0          0             0                 0        NaN  NaN
# 8           0          4             0                 0        NaN  NaN
# 9           0          0             0                 0        NaN  NaN
#
#   fielders_involved       BattingTeam     BowlingTeam
# 0               NaN  Rajasthan Royals  Gujarat Titans
# 1               NaN  Rajasthan Royals  Gujarat Titans
# 2               NaN  Rajasthan Royals  Gujarat Titans
# 3               NaN  Rajasthan Royals  Gujarat Titans
# 4               NaN  Rajasthan Royals  Gujarat Titans
# 5               NaN  Rajasthan Royals  Gujarat Titans
# 6               NaN  Rajasthan Royals  Gujarat Titans
# 7               NaN  Rajasthan Royals  Gujarat Titans
# 8               NaN  Rajasthan Royals  Gujarat Titans
# 9               NaN  Rajasthan Royals  Gujarat Titans

# %% [markdown]
# ## Since the above process took a lot of time to execute, we'll save the results of the data frame in a csv file

# %%
delivery.to_csv('Dataset/Processed_Data/Ball_By_Ball_Till_2022.csv')

# %% [markdown]
# ## Import features for predicting the winning team
# - Batting team
# - Bowling team
# - city
# - Runs_left
# - Balls_left
# - wickets_left
# - total_runs_x(Made by 1st inning team)
# - current_run_rate(CRR)
# - Required_run_rate(RRR)
# - result(Batting team Win or not)

# %% [markdown]
# ## Grouping these features

# %%
delivery.groupby(['ID','innings']).sum()['total_run']
##This will give the runs scored in innings 1 and 2 respectively in each match
# Out:
# ID       innings
# 335982   1          222
#          2           82
# 335983   1          240
#          2          207
# 335984   1          129
#                    ...
# 1312198  2          193
# 1312199  1          157
#          2          161
# 1312200  1          130
#          2          133
# Name: total_run, Length: 1928, dtype: int64

# %%
# convert into dataframe by runnig reset_index()
total_score_df = delivery.groupby(['ID','innings']).sum()['total_run'].reset_index()

# %%
total_score_df['total_run'] = total_score_df['total_run'] + 1 #Target

# %%
# Needed only 1st innings matches
total_score_df = total_score_df[total_score_df['innings'] == 1]

# %%
match_df = matches.merge(total_score_df[['ID','total_run']], left_on = 'ID',right_on = 'ID')
match_df.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# 3             Eden Gardens, Kolkata        Gujarat Titans        field  ...
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat  ...
#
#                    WinningTeam    WonBy Margin  method Player_of_Match  \
# 0               Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1             Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
# 2  Royal Challengers Bangalore     Runs   14.0     NaN      RM Patidar
# 3               Gujarat Titans  Wickets    7.0     NaN       DA Miller
# 4                 Punjab Kings  Wickets    5.0     NaN   Harpreet Brar
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2 total_run
# 0    Nitin Menon       131
# 1    Nitin Menon       158
# 2       MA Gough       208
# 3      VK Sharma       189
# 4  NA Patwardhan       158
#
# [5 rows x 21 columns]

# %%
match_df['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %% [markdown]
# ### NOTE:
# - Deccan Chargers -> Sunrises Hyderabad
# - Delhi Daredevils -> Delhi Capitals
# - Kings X1 Punjab -> Punjab Kings
# - {'Rising Pune Supergiants', 'Pune Warriors'} -> 'Rising Pune Supergiant'
# - Gujarat Lions -> Gujarat Titans

# %%
teams=['Sunrisers Hyderabad',
       'Mumbai Indians',
       'Royal Challengers Bangalore',
       'Kolkata Knight Riders',
       'Punjab Kings',
       'Chennai Super Kings',
       'Rajasthan Royals',
       'Delhi Capitals',
       'Lucknow Super Giants',
       'Gujarat Titans']
#Playing 10 teams

# %%
match_df['Team1']=match_df['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['Team2']=match_df['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['Team1']=match_df['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team2']=match_df['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['Team1']=match_df['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['Team2']=match_df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')

match_df['Team1']=match_df['Team1'].str.replace('Gujarat Lions','Gujarat Titans')
match_df['Team2']=match_df['Team2'].str.replace('Gujarat Lions','Gujarat Titans')

match_df['Team1']=match_df['Team1'].str.replace('Pune Warriors','Rising Pune Supergiant')
match_df['Team2']=match_df['Team2'].str.replace('Pune Warriors','Rising Pune Supergiant')

match_df['Team1']=match_df['Team1'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')
match_df['Team2']=match_df['Team2'].str.replace('Rising Pune Supergiants','Rising Pune Supergiant')



#Saving it as a CSV file so that this can be directly used in the future
match_df.to_csv('Dataset/Processed_Data/Matches_Till_2022.csv')

# %%
match_df['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala'], dtype=object)

# %% [markdown]
# ## As per the playing 10 teams

# %%
match_df=match_df[match_df['Team1'].isin(teams)]
match_df=match_df[match_df['Team2'].isin(teams)]

# %%
match_df['Team1'].unique()
#Rising Pune Supergiant and Kochi Tuskers Kerala have been removed
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians'], dtype=object)

# %%
match_df.shape
# Out:
# (861, 21)

# %% [markdown]
# ## Condensing the dataframe match_df.....We need only the city, winner and the target for prediction

# %%
match_df=match_df[['ID','City','WinningTeam','total_run']]
match_df
# Out:
#           ID        City                  WinningTeam  total_run
# 0    1312200   Ahmedabad               Gujarat Titans        131
# 1    1312199   Ahmedabad             Rajasthan Royals        158
# 2    1312198     Kolkata  Royal Challengers Bangalore        208
# 3    1312197     Kolkata               Gujarat Titans        189
# 4    1304116      Mumbai                 Punjab Kings        158
# ..       ...         ...                          ...        ...
# 945   335985      Mumbai  Royal Challengers Bangalore        166
# 946   335986     Kolkata        Kolkata Knight Riders        111
# 947   335984       Delhi             Delhi Daredevils        130
# 948   335983  Chandigarh          Chennai Super Kings        241
# 949   335982   Bangalore        Kolkata Knight Riders        223
#
# [861 rows x 4 columns]

# %%
# Merging the delivery and match_df dataframes
delivery_df=match_df.merge(delivery,on='ID')

#We're concerned with the second innings
delivery_df = delivery_df[delivery_df['innings'] == 2]
delivery_df.head(5)
# Out:
#           ID       City     WinningTeam  total_run_x             Team1  \
# 120  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 121  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 122  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 123  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 124  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
#
#               Team2  innings  overs  ballnumber        batter  ...  \
# 120  Gujarat Titans        2      0           1       WP Saha  ...
# 121  Gujarat Titans        2      0           2       WP Saha  ...
# 122  Gujarat Titans        2      0           3       WP Saha  ...
# 123  Gujarat Titans        2      0           4  Shubman Gill  ...
# 124  Gujarat Titans        2      0           5  Shubman Gill  ...
#
#     batsman_run extras_run total_run_y  non_boundary  isWicketDelivery  \
# 120           0          0           0             0                 0
# 121           0          0           0             0                 0
# 122           1          0           1             0                 0
# 123           0          0           0             0                 0
# 124           0          0           0             0                 0
#
#      player_out  kind  fielders_involved     BattingTeam       BowlingTeam
# 120         NaN   NaN                NaN  Gujarat Titans  Rajasthan Royals
# 121         NaN   NaN                NaN  Gujarat Titans  Rajasthan Royals
# 122         NaN   NaN                NaN  Gujarat Titans  Rajasthan Royals
# 123         NaN   NaN                NaN  Gujarat Titans  Rajasthan Royals
# 124         NaN   NaN                NaN  Gujarat Titans  Rajasthan Royals
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Finding out the total runs made after each ball using cummulative sum

# %%
delivery_df['current_score'] = delivery_df.groupby('ID').cumsum()['total_run_y']
delivery_df['current_score']
# Out:
# 120        0
# 121        0
# 122        1
# 123        1
# 124        1
#           ..
# 205076    80
# 205077    81
# 205078    81
# 205079    82
# 205080    82
# Name: current_score, Length: 98901, dtype: int64

# %%
delivery_df.head(5)
# Out:
#           ID       City     WinningTeam  total_run_x             Team1  \
# 120  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 121  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 122  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 123  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 124  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
#
#               Team2  innings  overs  ballnumber        batter  ... extras_run  \
# 120  Gujarat Titans        2      0           1       WP Saha  ...          0
# 121  Gujarat Titans        2      0           2       WP Saha  ...          0
# 122  Gujarat Titans        2      0           3       WP Saha  ...          0
# 123  Gujarat Titans        2      0           4  Shubman Gill  ...          0
# 124  Gujarat Titans        2      0           5  Shubman Gill  ...          0
#
#     total_run_y non_boundary  isWicketDelivery  player_out  kind  \
# 120           0            0                 0         NaN   NaN
# 121           0            0                 0         NaN   NaN
# 122           1            0                 0         NaN   NaN
# 123           0            0                 0         NaN   NaN
# 124           0            0                 0         NaN   NaN
#
#      fielders_involved     BattingTeam       BowlingTeam current_score
# 120                NaN  Gujarat Titans  Rajasthan Royals             0
# 121                NaN  Gujarat Titans  Rajasthan Royals             0
# 122                NaN  Gujarat Titans  Rajasthan Royals             1
# 123                NaN  Gujarat Titans  Rajasthan Royals             1
# 124                NaN  Gujarat Titans  Rajasthan Royals             1
#
# [5 rows x 24 columns]

# %%
## Adding other necessary attributes
delivery_df['runs_left'] = delivery_df['total_run_x'] - delivery_df['current_score']

delivery_df['balls_left'] = 120 - (delivery_df['overs'] * 6 + delivery_df['ballnumber'])

delivery_df['player_out'] = delivery_df['player_out'].fillna("0")
delivery_df['player_out'] = delivery_df['player_out'].apply(lambda x:x if x == "0" else "1")
delivery_df['player_out']=delivery_df['player_out'].astype('int')

wickets = delivery_df.groupby('ID').cumsum()['player_out'].values
delivery_df['wickets']= 10 - wickets

delivery_df.head(5)
# Out:
#           ID       City     WinningTeam  total_run_x             Team1  \
# 120  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 121  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 122  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 123  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 124  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
#
#               Team2  innings  overs  ballnumber        batter  ...  \
# 120  Gujarat Titans        2      0           1       WP Saha  ...
# 121  Gujarat Titans        2      0           2       WP Saha  ...
# 122  Gujarat Titans        2      0           3       WP Saha  ...
# 123  Gujarat Titans        2      0           4  Shubman Gill  ...
# 124  Gujarat Titans        2      0           5  Shubman Gill  ...
#
#     isWicketDelivery player_out kind  fielders_involved     BattingTeam  \
# 120                0          0  NaN                NaN  Gujarat Titans
# 121                0          0  NaN                NaN  Gujarat Titans
# 122                0          0  NaN                NaN  Gujarat Titans
# 123                0          0  NaN                NaN  Gujarat Titans
# 124                0          0  NaN                NaN  Gujarat Titans
#
#           BowlingTeam  current_score  runs_left  balls_left wickets
# 120  Rajasthan Royals              0        131         119      10
# 121  Rajasthan Royals              0        131         118      10
# 122  Rajasthan Royals              1        130         117      10
# 123  Rajasthan Royals              1        130         116      10
# 124  Rajasthan Royals              1        130         115      10
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Current Run Rate (CRR)

# %%
#crr= runs_made_till now/overs(in fraction)
delivery_df['crr'] = (delivery_df['current_score'] * 6)/(120 - delivery_df['balls_left'])
delivery_df['crr']
# Out:
# 120       0.000000
# 121       0.000000
# 122       2.000000
# 123       1.500000
# 124       1.200000
#             ...
# 205076    5.393258
# 205077    5.400000
# 205078    5.340659
# 205079    5.406593
# 205080    5.347826
# Name: crr, Length: 98901, dtype: float64

# %% [markdown]
# ## Required Run Rate (RRR)

# %%
# rrr = runs_left / overs
delivery_df['rrr'] = (delivery_df['runs_left'] * 6) / delivery_df['balls_left']
delivery_df['rrr']
# Out:
# 120        6.605042
# 121        6.661017
# 122        6.666667
# 123        6.724138
# 124        6.782609
#             ...
# 205076    27.677419
# 205077    28.400000
# 205078    29.379310
# 205079    29.172414
# 205080    30.214286
# Name: rrr, Length: 98901, dtype: float64

# %% [markdown]
# ## Some stats

# %%
df = matches[(matches['WinningTeam'] == 'Chennai Super King') & (matches['Season'] == '2016') ].groupby(['Season'])['ID'].count()
df.empty
#Because in 2016 SRH won
# Out:
# True

# %%
#Total matches played by Mumbai Indians Season Wise
matches[(matches['Team1'] == 'Mumbai Indians') | (matches['Team2'] == 'Mumbai Indians') ].groupby(['Season'])['ID'].count()
# Out:
# Season
# 2008    14
# 2009    13
# 2010    16
# 2011    16
# 2012    17
# 2013    19
# 2014    15
# 2015    16
# 2016    14
# 2017    17
# 2018    14
# 2019    16
# 2020    16
# 2021    14
# 2022    14
# Name: ID, dtype: int64

# %% [markdown]
# ## Match wins for each team in 2022 season

# %%
match_wins = matches[matches['Season']=='2022']['WinningTeam'].value_counts()
match_wins

#Note it's not a fully updated dataset....at this stage MI didn't win any match and hence is not in the list
# Out:
# Gujarat Titans                 12
# Rajasthan Royals               10
# Royal Challengers Bangalore     9
# Lucknow Super Giants            9
# Punjab Kings                    7
# Delhi Capitals                  7
# Sunrisers Hyderabad             6
# Kolkata Knight Riders           6
# Mumbai Indians                  4
# Chennai Super Kings             4
# Name: WinningTeam, dtype: int64

# %%
df = matches[(matches['WinningTeam'] == 'Chennai Super Kings')].groupby(['Season'])['ID'].count()
dict(df)
df.get('2009')
# Out:
# 8

# %%
plt.figure(figsize=(10,7))
ax = sns.barplot(match_wins.index, match_wins.values, alpha = 0.8)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40, ha = "right")

plt.title('Performance of Each Team')
plt.ylabel('Number of Match Wins in the Season', fontsize = 12)
plt.xlabel('Teams', fontsize = 12)
plt.tight_layout()
plt.show()

# %%
def result(row):
    return 1 if row['BattingTeam'] == row['WinningTeam'] else 0

delivery_df['result'] = delivery_df.apply(result, axis = 1)
delivery_df['result']
# Out:
# 120       1
# 121       1
# 122       1
# 123       1
# 124       1
#          ..
# 205076    0
# 205077    0
# 205078    0
# 205079    0
# 205080    0
# Name: result, Length: 98901, dtype: int64

# %% [markdown]
# ## Final dataset after feature engineering, this will be used to train the ML model

# %%
# final_df = delivery_df[['Batting_Team','Bowling_team','City','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]
# final_df

data = {
    'Batting_Team': delivery_df['BattingTeam'],
    'Bowling_team': delivery_df['BowlingTeam'],
    'City': delivery_df['City'],
    'runs_left': delivery_df['runs_left'],
    'balls_left': delivery_df['balls_left'],
    'wickets': delivery_df['wickets'],
    'total_runs_x': delivery_df['total_run_x'],
    'crr': delivery_df['crr'],
    'rrr': delivery_df['rrr'],
    'result': delivery_df['result'] 
}

final_df = pd.DataFrame(data)
final_df

# final_df['result'] shows the batting team in the 2nd Innings is a winner or not.
# Out:
#                        Batting_Team           Bowling_team       City  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 122                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 123                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 124                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 205076  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205077  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205078  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205079  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205080  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#         runs_left  balls_left  wickets  total_runs_x       crr        rrr  \
# 120           131         119       10           131  0.000000   6.605042
# 121           131         118       10           131  0.000000   6.661017
# 122           130         117       10           131  2.000000   6.666667
# 123           130         116       10           131  1.500000   6.724138
# 124           130         115       10           131  1.200000   6.782609
# ...           ...         ...      ...           ...       ...        ...
# 205076        143          31        1           223  5.393258  27.677419
# 205077        142          30        1           223  5.400000  28.400000
# 205078        142          29        1           223  5.340659  29.379310
# 205079        141          29        1           223  5.406593  29.172414
# 205080        141          28        0           223  5.347826  30.214286
#
#         result
# 120          1
# 121          1
# 122          1
# 123          1
# 124          1
# ...        ...
# 205076       0
# 205077       0
# 205078       0
# 205079       0
# 205080       0
#
# [98901 rows x 10 columns]

# %%
final_df = final_df.sample(final_df.shape[0])
final_df.isnull().sum()
# Out:
# Batting_Team       0
# Bowling_team       0
# City            6012
# runs_left          0
# balls_left         0
# wickets            0
# total_runs_x       0
# crr                0
# rrr               11
# result             0
# dtype: int64

# %%
final_df.dropna(inplace = True)

final_df = final_df[final_df['balls_left']!=0]   # we don't want INF rrr
final_df
# Out:
#                        Batting_Team                 Bowling_team  \
# 128098              Kings XI Punjab          Sunrisers Hyderabad
# 82659         Kolkata Knight Riders             Delhi Daredevils
# 4767                 Delhi Capitals          Chennai Super Kings
# 55280           Chennai Super Kings             Rajasthan Royals
# 43078   Royal Challengers Bangalore             Rajasthan Royals
# ...                             ...                          ...
# 15464           Chennai Super Kings                 Punjab Kings
# 181325              Kings XI Punjab             Delhi Daredevils
# 178907              Deccan Chargers  Royal Challengers Bangalore
# 174095               Mumbai Indians        Kolkata Knight Riders
# 43835               Kings XI Punjab               Mumbai Indians
#
#                 City  runs_left  balls_left  wickets  total_runs_x       crr  \
# 128098    Chandigarh         51          21        6           151  6.060606
# 82659          Delhi         10           8        5           169  8.517857
# 4767     Navi Mumbai        120          44        3           209  7.026316
# 55280         Jaipur        137          97        8           152  3.913043
# 43078      Abu Dhabi        123          97        9           155  8.347826
# ...              ...        ...         ...      ...           ...       ...
# 15464         Mumbai         76          28        3           181  6.847826
# 181325  Bloemfontein         86          87        7           121  6.363636
# 178907     Centurion         73          46        8           171  7.945946
# 174095        Mumbai         33          28        8           156  8.021739
# 43835      Abu Dhabi        151          83        8           192  6.648649
#
#               rrr  result
# 128098  14.571429       0
# 82659    7.500000       1
# 4767    16.363636       0
# 55280    8.474227       1
# 43078    7.608247       1
# ...           ...     ...
# 15464   16.285714       0
# 181325   5.931034       1
# 178907   9.521739       0
# 174095   7.071429       1
# 43835   10.915663       0
#
# [92581 rows x 10 columns]

# %%
final_df.to_csv('Dataset/Processed_Data/Final_Dataset_After_Feature_Engineering.csv')

# %% [markdown]
# ## Splitting into training and test data

# %%
X=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                        Batting_Team                 Bowling_team       City  \
# 164400  Royal Challengers Bangalore               Mumbai Indians     Mumbai
# 38123           Sunrisers Hyderabad        Kolkata Knight Riders  Abu Dhabi
# 93282           Sunrisers Hyderabad              Kings XI Punjab  Hyderabad
# 195930              Kings XI Punjab             Delhi Daredevils      Delhi
# 181895  Royal Challengers Bangalore          Chennai Super Kings     Durban
# ...                             ...                          ...        ...
# 62386                Mumbai Indians             Delhi Daredevils      Delhi
# 132401        Kolkata Knight Riders              Kings XI Punjab    Kolkata
# 70231                Mumbai Indians          Sunrisers Hyderabad     Mumbai
# 52923         Kolkata Knight Riders  Royal Challengers Bangalore    Kolkata
# 72210         Kolkata Knight Riders             Rajasthan Royals     Jaipur
#
#         runs_left  balls_left  wickets  total_runs_x       crr        rrr
# 164400         66          28        3           185  7.760870  14.142857
# 38123         143         104       10           164  7.875000   8.250000
# 93282         138         114       10           144  6.000000   7.263158
# 195930        117         116       10           119  3.000000   6.051724
# 181895          9           9        3           130  6.540541   6.000000
# ...           ...         ...      ...           ...       ...        ...
# 62386          76          48        5           175  8.250000   9.500000
# 132401          1          10        6           150  8.127273   0.600000
# 70231          92          76        7           119  3.681818   7.263158
# 52923         113          36        6           214  7.214286  18.833333
# 72210           6           9        7           161  8.378378   4.000000
#
# [74064 rows x 9 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['Batting_Team','Bowling_team','City'])
]
,remainder='passthrough')

# %% [markdown]
# ## Training the Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Logistic Regression

# %%
LogReg=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
LogReg.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['Batting_Team',
#                                                    'Bowling_team', 'City'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %% [markdown]
# ## Random Forest

# %%
Rf=Pipeline(steps=[
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

# %%
Rf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['Batting_Team',
#                                                    'Bowling_team', 'City'])])),
#                 ('step2', RandomForestClassifier())])

# %% [markdown]
# ## Decision Tree Classification

# %%
dt_clf=Pipeline(steps=[
    ('step1',trf),
    ('step2',DecisionTreeClassifier(max_depth=10, random_state = 42))
])

# %%
dt_clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['Batting_Team',
#                                                    'Bowling_team', 'City'])])),
#                 ('step2',
#                  DecisionTreeClassifier(max_depth=10, random_state=42))])

# %%
X_train.describe()
# Out:
#           runs_left    balls_left       wickets  total_runs_x           crr  \
# count  74064.000000  74064.000000  74064.000000   74064.00000  74064.000000
# mean      93.045474     63.067185      7.561771     166.07025      7.472143
# std       49.750266     33.266894      2.133942      28.82326      2.273622
# min      -15.000000     -2.000000      0.000000      63.00000      0.000000
# 25%       54.000000     35.000000      6.000000     148.00000      6.294118
# 50%       92.000000     64.000000      8.000000     166.00000      7.513514
# 75%      131.000000     92.000000      9.000000     186.00000      8.718750
# max      249.000000    119.000000     10.000000     249.00000     36.000000
#
#                 rrr
# count  74064.000000
# mean      10.466058
# std       14.220388
# min     -516.000000
# 25%        7.200000
# 50%        8.891238
# 75%       10.909091
# max      714.000000

# %%
y_test.value_counts()      # Ratio is almost 1:1
# Out:
# 1    9908
# 0    8609
# Name: result, dtype: int64

# %% [markdown]
# ## Accuracy of Each Model

# %%
y_pred=LogReg.predict(X_test)

# %%
# Logistic Regression
accuracy_score(y_test,y_pred)
# Out:
# 0.8186531295566236

# %%
y_pred=Rf.predict(X_test)

# %%
# random forest
accuracy_score(y_test,y_pred)
# Out:
# 0.9981098450072906

# %%
y_pred=dt_clf.predict(X_test)

# %%
# D-Tree
accuracy_score(y_test,y_pred)
# Out:
# 0.8559701895555436

# %%
import pickle
pickle.dump(LogReg, open('LogReg.pkl', 'wb'))
pickle.dump(Rf, open('Rf.pkl', 'wb'))
pickle.dump(dt_clf, open('dt_clf.pkl', 'wb'))
